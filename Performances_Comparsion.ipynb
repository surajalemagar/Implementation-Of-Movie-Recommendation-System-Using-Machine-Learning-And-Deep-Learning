# %%
import matplotlib.pyplot as plt
import pandas as pd

# Example data
data = {
    'Model': ['KNNWithMeans', 'SVD', 'SVD++', 'NMF', 'BaselineOnly', 'Neural Collaborative Filtering', 'Wide and Deep Model', 'Transformer Model'],
    'MSE': [0.819, 0.768, 0.746, 0.851, 0.757, 0.840, 0.889, 0.767],
    'RMSE': [0.905, 0.876, 0.864, 0.922, 0.870, 0.916, 0.943, 0.870],
    'MAE': [0.692, 0.673, 0.662, 0.708, 0.670, 0.697, 0.731, 0.665]
}

df = pd.DataFrame(data)

# Plot
df.plot(x='Model', kind='bar', figsize=(14, 8), width=0.8)
plt.title('Comparison of MSE, RMSE, and MAE for Different Models')
plt.xlabel('Model')
plt.ylabel('Score')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Metrics')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Example data
data = {
    'Model': ['KNNWithMeans', 'SVD', 'SVD++', 'NMF', 'BaselineOnly', 'Neural Collaborative Filtering', 'Wide and Deep Model', 'Transformer Model'],
    'MSE': [0.819, 0.768, 0.746, 0.851, 0.757, 0.840, 0.889, 0.767],
    'RMSE': [0.905, 0.876, 0.864, 0.922, 0.870, 0.916, 0.943, 0.870],
    'MAE': [0.692, 0.673, 0.662, 0.708, 0.670, 0.697, 0.731, 0.665]
}

df = pd.DataFrame(data)

# Set figure size
plt.figure(figsize=(14, 8))

# Plot
ax = df.plot(x='Model', kind='bar', figsize=(14, 8), width=0.8, colormap='viridis', edgecolor='black')

# Add data labels
for container in ax.containers:
    ax.bar_label(container, fmt='%.3f', label_type='edge', fontsize=10, color='black', weight='bold')

# Customize the plot
plt.title('Comparison of MSE, RMSE, and MAE for Different Models', fontsize=16, weight='bold')
plt.xlabel('Model', fontsize=14)
plt.ylabel('Score', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(title='Metrics', title_fontsize='13', fontsize='12')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
models = ['KNNWithMeans', 'SVD', 'SVD++', 'NMF', 'BaselineOnly', 'Neural Collaborative Filtering', 'Wide and Deep Model', 'Transformer Model']
training_times = [0.42, 1.62, 83.13, 2.54, 0.11, 32.01, 63.08, 92.70]

# Plot
plt.figure(figsize=(12, 6))
plt.plot(models, training_times, marker='o', linestyle='-', color='b')
plt.title('Training Time of Different Models')
plt.xlabel('Model')
plt.ylabel('Training Time (Seconds)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
models = ['KNNWithMeans', 'SVD', 'SVD++', 'NMF', 'BaselineOnly', 'Neural Collaborative Filtering', 'Wide and Deep Model', 'Transformer Model']
training_times = [0.42, 1.62, 83.13, 2.54, 0.11, 32.01, 63.08, 92.70]

# Plot
plt.figure(figsize=(14, 7))
plt.plot(models, training_times, marker='o', linestyle='-', color='teal', markersize=8, linewidth=2, markeredgewidth=2)

# Add data labels
for i, txt in enumerate(training_times):
    plt.text(models[i], training_times[i] + 2, f'{txt:.2f}', ha='center', va='bottom', fontsize=10, weight='bold')

# Customize the plot
plt.title('Training Time of Different Models', fontsize=16, weight='bold')
plt.xlabel('Model', fontsize=14)
plt.ylabel('Training Time (Seconds)', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Data
metrics = {
    'Model': ['KNNWithMeans', 'SVD', 'SVD++', 'NMF', 'BaselineOnly', 'Neural Collaborative Filtering', 'Wide and Deep Model', 'Transformer Model'],
    'MSE': [0.819, 0.768, 0.746, 0.851, 0.757, 0.840, 0.889, 0.767],
    'RMSE': [0.905, 0.876, 0.864, 0.922, 0.870, 0.916, 0.943, 0.870],
    'MAE': [0.692, 0.673, 0.662, 0.708, 0.670, 0.697, 0.731, 0.665]
}

df_metrics = pd.DataFrame(metrics).set_index('Model')

# Plot
plt.figure(figsize=(12, 8))
sns.heatmap(df_metrics, annot=True, cmap='YlGnBu', fmt='.3f')
plt.title('Heatmap of MSE, RMSE, and MAE for Different Models')
plt.xlabel('Metric')
plt.ylabel('Model')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data for MSE
data = {
    'Model': ['KNNWithMeans', 'SVD', 'SVD++', 'NMF', 'BaselineOnly', 'Neural Collaborative Filtering', 'Wide and Deep Model', 'Transformer Model'],
    'MSE': [0.819, 0.768, 0.746, 0.851, 0.757, 0.840, 0.889, 0.767]
}

df = pd.DataFrame(data)

# Plot
plt.figure(figsize=(12, 6))
plt.bar(df['Model'], df['MSE'], color='skyblue')
plt.title('Mean Squared Error (MSE) for Different Models')
plt.xlabel('Model')
plt.ylabel('MSE')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data for RMSE
data = {
    'Model': ['KNNWithMeans', 'SVD', 'SVD++', 'NMF', 'BaselineOnly', 'Neural Collaborative Filtering', 'Wide and Deep Model', 'Transformer Model'],
    'RMSE': [0.905, 0.876, 0.864, 0.922, 0.870, 0.916, 0.943, 0.870]
}

df = pd.DataFrame(data)

# Plot
plt.figure(figsize=(12, 6))
plt.bar(df['Model'], df['RMSE'], color='lightgreen')
plt.title('Root Mean Squared Error (RMSE) for Different Models')
plt.xlabel('Model')
plt.ylabel('RMSE')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data for MAE
data = {
    'Model': ['KNNWithMeans', 'SVD', 'SVD++', 'NMF', 'BaselineOnly', 'Neural Collaborative Filtering', 'Wide and Deep Model', 'Transformer Model'],
    'MAE': [0.692, 0.673, 0.662, 0.708, 0.670, 0.697, 0.731, 0.665]
}

df = pd.DataFrame(data)

# Plot
plt.figure(figsize=(12, 6))
plt.bar(df['Model'], df['MAE'], color='salmon')
plt.title('Mean Absolute Error (MAE) for Different Models')
plt.xlabel('Model')
plt.ylabel('MAE')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data for Training Time
data = {
    'Model': ['KNNWithMeans', 'SVD', 'SVD++', 'NMF', 'BaselineOnly', 'Neural Collaborative Filtering', 'Wide and Deep Model', 'Transformer Model'],
    'Training Time (Seconds)': [0.42, 1.62, 83.13, 2.54, 0.11, 32.01, 63.08, 92.70]
}

df = pd.DataFrame(data)

# Plot
plt.figure(figsize=(12, 6))
plt.bar(df['Model'], df['Training Time (Seconds)'], color='purple')
plt.title('Training Time for Different Models')
plt.xlabel('Model')
plt.ylabel('Training Time (Seconds)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data for MSE
data = {
    'Model': ['KNNWithMeans', 'SVD', 'SVD++', 'NMF', 'BaselineOnly', 'Neural Collaborative Filtering', 'Wide and Deep Model', 'Transformer Model'],
    'MSE': [0.819, 0.768, 0.746, 0.851, 0.757, 0.840, 0.889, 0.767]
}

df = pd.DataFrame(data)

# Plot
plt.figure(figsize=(12, 6))
plt.barh(df['Model'], df['MSE'], color='skyblue')
plt.title('Mean Squared Error (MSE) for Different Models')
plt.xlabel('MSE')
plt.ylabel('Model')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data for RMSE
data = {
    'Model': ['KNNWithMeans', 'SVD', 'SVD++', 'NMF', 'BaselineOnly', 'Neural Collaborative Filtering', 'Wide and Deep Model', 'Transformer Model'],
    'RMSE': [0.905, 0.876, 0.864, 0.922, 0.870, 0.916, 0.943, 0.870]
}

df = pd.DataFrame(data)

# Plot
plt.figure(figsize=(12, 6))
plt.barh(df['Model'], df['RMSE'], color='lightgreen')
plt.title('Root Mean Squared Error (RMSE) for Different Models')
plt.xlabel('RMSE')
plt.ylabel('Model')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Data for MAE
data = {
    'Model': ['KNNWithMeans', 'SVD', 'SVD++', 'NMF', 'BaselineOnly', 'Neural Collaborative Filtering', 'Wide and Deep Model', 'Transformer Model'],
    'MAE': [0.692, 0.673, 0.662, 0.708, 0.670, 0.697, 0.731, 0.665]
}

df = pd.DataFrame(data)

# Plot
plt.figure(figsize=(12, 6))
sns.boxplot(x='MAE', data=df, palette='pastel')
plt.title('Mean Absolute Error (MAE) Distribution Across Models')
plt.xlabel('MAE')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-11-78835cec5092>:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='MAE', data=df, palette='pastel')
